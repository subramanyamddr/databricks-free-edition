# %% [markdown]
# my approach

# %%
input = "hello"
output = {}

for x in input:
    if x not in output:
        output[x]=1
    else:
        output[x]+=1

print(output)

# %% [markdown]
# system approach

# %%
input = "hello"
from collections import Counter

output = dict(Counter(input))
display(output)
