# %%
# %sql
select * from framework_catalog.framework.pipeline_config;
select * from framework_catalog.framework.pipeline_audit  ;
select * from framework_catalog.framework.dq_rules        ;
select * from framework_catalog.framework.dq_results      ;
select * from framework_catalog.framework.quarantine      ;
select * from framework_catalog.framework.schema_registry ;

# %%
# %sql
select * from framework_catalog.framework.pipeline_config;

# %%
# %sql
select * from framework_catalog.framework.pipeline_audit  ;
