# %%
# Define variables
storage_account_name = "mrhladlsdev"
container_name = "mrhl-mro"

client_id = "ef90b0f7-39c3-45b7-ae2f-d1e160bcb47d"        # App (client) ID
tenant_id = "a3d3d0f0-6b19-40dc-a740-67ee247d38f0"         # Directory (tenant) ID
client_secret = "xx"                       # Client secret value


file_path = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net/raw/emp.csv"

df = spark.read.format("csv").options(header=True).options(**{
  "fs.azure.account.auth.type": "OAuth",
  "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  "fs.azure.account.oauth2.client.id": client_id,
  "fs.azure.account.oauth2.client.secret": client_secret,
  "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"
}).load(file_path, header=True, inferSchema=True)

df.display()
