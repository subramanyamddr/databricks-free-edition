# %%
# %sql
create volume if not exists dev.bronze.landing
comment 'creating landing volumn'

# %%
dbutils.fs.mkdirs('/Volumes/dev/bronze/landing/input')

# %%
dbutils.fs.cp(
    "/databricks-datasets/definitive-guide/data/retail-data/by-day/2010-12-05.csv",
    "/Volumes/dev/bronze/landing/input/2010-12-05.csv"
)

# %%
# %sql
create table dev.bronze.invoice_cp;

# %%
# %sql
copy into dev.bronze.invoice_cp
from '/Volumes/dev/bronze/landing/input/'
fileformat = csv
pattern ="*.csv"
format_options(
  'mergeschema' = 'True',
  'header'='true'
)
copy_options(
  'mergeschema'='true'
)

# %%
# %sql
select count(1) from dev.bronze.invoice_cp

# %%
# %sql
describe extended dev.bronze.invoice_cp

# %% [markdown]
# creating table with required columns

# %%
# %sql
create table dev.bronze.invoice_cp_select_columns(
  InvoiceNo string,
  StockCode string,
  Description string,
  _insert_date timestamp 
);

# %%
# %sql
copy into dev.bronze.invoice_cp_select_columns
from (select InvoiceNo,StockCode,Description,current_timestamp() as _insert_date 
  FROM '/Volumes/dev/bronze/landing/input/')
fileformat = csv
pattern = "*.csv"
format_options(
  'mergeschema' = 'True',
  'header'='true'
)

# %%
# %sql
select * from dev.bronze.invoice_cp_select_columns
