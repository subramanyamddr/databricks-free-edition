# %%
# %sql
table practice.write_mode.emp_table_partition

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

data = [
    (4, "subbu1", "5000"),
    (5, "davala1", "abc"),
    (8, "man1", "7000")
]

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("salary", StringType(), True)
])

df = spark.createDataFrame(data, schema)
display(df)

# %%
df.write.format('delta').mode('append').partitionBy('id').saveAsTable('practice.write_mode.emp_table_partition')

# %%
# %sql
table practice.write_mode.emp_table_partition

# %%
# %sql
describe extended practice.write_mode.emp_table_partition
