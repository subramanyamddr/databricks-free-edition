# %%
# %sql
select * from samples.wanderbricks.employees;

# %%
# %sql
select * from samples.wanderbricks.hosts;

# %%
# %sql
select * from  dev.sdp81.wander_hosts

# %%
# %sql
select * from dev.sdp81.wander_employee

# %%
# %sql
create schema if not exists dev.sdp81

# %%
# %sql
create table if not exists dev.sdp81.wander_employee deep clone samples.wanderbricks.employees;

# %%
# %sql
create table if not exists dev.sdp81.wander_destinations deep clone samples.wanderbricks.destinations;

# %%
# %sql
create table if not exists dev.sdp81.wander_hosts deep clone samples.wanderbricks.hosts;
